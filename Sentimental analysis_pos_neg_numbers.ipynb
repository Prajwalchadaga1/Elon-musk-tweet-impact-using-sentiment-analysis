# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from bs4 import BeautifulSoup
import re


# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

from subprocess import check_output

# Any results you write to the current directory are saved as output.
tweets=pd.read_csv("Elon_musk_tweets.csv",encoding = "ISO-8859-1")
tweets.shape
tweets.head()

#We will use:
#1.BeautifulSoup to remove HTML
#2.Then we will remove non-letters and will split the sentences into words
#3.Removal of Stopwords

def clean(x):
    #Remove Html  
    x=BeautifulSoup(x).get_text()
    
    #Remove Non-Letters
    x=re.sub('[^a-zA-Z]',' ',x)
    
    #Convert to lower_case and split
    x=x.lower().split()
    
    #Remove stopwords
    stop=set(stopwords.words('english'))
    words=[w for w in x if not w in stop]
    
    #join the words back into one string
    return(' '.join(words))

tweets.Tweet=tweets.Tweet.apply(lambda x:clean(x))
tweets.head()


from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.sentiment.util import *

from nltk import tokenize

sid = SentimentIntensityAnalyzer()

tweets['sentiment_compound_polarity']=tweets.Tweet.apply(lambda x:sid.polarity_scores(x)['compound'])

tweets['sentiment_negative']=tweets.Tweet.apply(lambda x:sid.polarity_scores(x)['neg'])
tweets['sentiment_pos']=tweets.Tweet.apply(lambda x:sid.polarity_scores(x)['pos'])
tweets['sentiment']=''
tweets.loc[tweets.sentiment_compound_polarity>=0,'sentiment']=1

tweets.loc[tweets.sentiment_compound_polarity<0,'sentiment']=0
tweets.shape
tweets.head()

tweets.to_csv("Elon_musk_tweets_with_sentiments_numbers.csv",sep='\t', encoding='ISO-8859-1')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\prajw\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/IypZm9FdQk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/is6Hthjjoj" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/tj4FrDw34z" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/spUaZYaxgB" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/Uu6DQa3Kx4" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/3YSXZq1EVj" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/6Ve3YJoStm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/Kgkz1Z3FwJ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/3k71xzDIP1" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/LYJOL0T7sC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/nhB3gd0Gm6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/pNElNTmcKf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/wJDmXrEuKi" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/v8tKtzcANg" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/C98mW0OPAF" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/UWJK1LwgKf" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/dEOd5GKfdk" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/JIl6vzhQAx" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/MMRtF3jHD5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/OgAHAWkNkU" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/8nnlWHUjXw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/5CS4McZmPK" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/SiIkkugFyC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/nYUdW7JMXC" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/D1umiFDr1t" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/ys9qlwcnpc" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/PctxEIDekX" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/Q9JE06lmWN" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/d1KEp44zjm" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/dUpiavvM1Z" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/nqgfNWlm4Z" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/Fn0hKJd3uJ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/kB6RBscyYH" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/xGJ4Bc6HpL" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/gt8PXloMZn" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/TQhb9hQRxQ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/E8fhyjN0pD" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:273: UserWarning: "b'...'" looks like a filename, not markup. You should probably open this file and pass the filehandle into Beautiful Soup.
#   ' Beautiful Soup.' % markup)
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/Vl6pIb1q9b" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/gTaURPZral" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/ChEGbjTGKZ" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/yFhNx3fiOD" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/JufeavpKj6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/OA5Q8NnsNR" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/48s5D3IfWs" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/bhKdyN5hR6" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/KTItxbXTbG" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/GcsHAMgnXz" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/yUUSNdWMEw" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/FiJ0U2eNX5" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/3DGSWBfQTq" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/NLzW87AZC0" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/GXMnkpDNb3" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
# C:\Users\prajw\Anaconda3\lib\site-packages\bs4\__init__.py:336: UserWarning: "https://t.co/BkKeiIzNPM" looks like a URL. Beautiful Soup is not an HTTP client. You should probably use an HTTP client like requests to get the document behind the URL, and feed that document to Beautiful Soup.
#   ' that document to Beautiful Soup.' % decoded_markup
